# %% [markdown]
# # Set up the environment to perform exploratory analysis

# %%
from time import time
import configparser
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %load_ext sql

# %%
config = configparser.ConfigParser()
config.read_file(open('../3-iac/aws.cfg'))

DWH_DB= config.get("DWH","DWH_DB")
DWH_DB_USER= config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD= config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT = config.get("DWH","DWH_PORT")
DWH_ENDPOINT = "dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com"

# %%
import os 
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
# %sql $conn_string
# Out:
# 'Connected: dwhuser@dwh'

# %% [markdown]
# ## Average Temperature by Country in 2010
#
# The temperature is ordered from the hottest to the coldest country

# %%
# %%sql
# select co.short_name, co.alpha2_code, co.region, avg(tem.avg_temperature) as temperature
# from dim_country co
#   join fact_temperatures_by_country tem on co.country_code = tem.country_code
#   join dim_date da on tem.full_date = da.full_date
# where da.year = 2010
# group by co.short_name, co.alpha2_code, co.region
# order by temperature desc;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 176 rows affected.
# [('Mali', 'ML', 'Sub-Saharan Africa', 30.1270833333333),
#  ('Djibouti', 'DJ', 'Middle East & North Africa', 29.837),
#  ('United Arab Emirates', 'AE', 'Middle East & North Africa', 29.6713333333333),
#  ('Mauritania', 'MR', 'Sub-Saharan Africa', 29.3729166666667),
#  ('Senegal', 'SN', 'Sub-Saharan Africa', 29.3023333333333),
#  ('Niger', 'NE', 'Sub-Saharan Africa', 29.2999166666667),
#  ('Burkina Faso', 'BF', 'Sub-Saharan Africa', 29.28875),
#  ('Aruba', 'AW', 'Latin America & Caribbean', 28.9683333333333),
#  ('Qatar', 'QA', 'Middle East & North Africa', 28.8895833333333),
#  ('Chad', 'TD', 'Sub-Saharan Africa', 28.6965),
#  ('Sudan', 'SD', 'Sub-Saharan Africa', 28.6476666666667),
#  ('Curaçao', 'CW', 'Latin America & Caribbean', 28.4735),
#  ('Oman', 'OM', 'Middle East & North Africa', 28.4586666666667),
#  ('Benin', 'BJ', 'Sub-Saharan Africa', 28.3255833333333),
#  ('Grenada', 'GD', 'Latin America & Caribbean', 28.1089166666667),
#  ('Bahrain', 'BH', 'Middle East & North Africa', 28.0696666666667),
#  ('Togo', 'TG', 'Sub-Saharan Africa', 28.0594166666667),
#  ('Eritrea', 'ER', 'Sub-Saharan Africa', 28.0541666666667),
#  ('Nigeria', 'NG', 'Sub-Saharan Africa', 28.00425),
#  ('Ghana', 'GH', 'Sub-Saharan Africa', 27.935),
#  ('Sri Lanka', 'LK', 'South Asia', 27.8835),
#  ('Cambodia', 'KH', 'East Asia & Pacific', 27.87525),
#  ('Barbados', 'BB', 'Latin America & Caribbean', 27.8446666666667),
#  ('Somalia', 'SO', 'Sub-Saharan Africa', 27.821),
#  ('Palau', 'PW', 'East Asia & Pacific', 27.76775),
#  ('Seychelles', 'SC', 'Sub-Saharan Africa', 27.7448333333333),
#  ('Kuwait', 'KW', 'Middle East & North Africa', 27.6386666666667),
#  ('Singapore', 'SG', 'East Asia & Pacific', 27.6035),
#  ('Virgin Islands', 'VI', 'Latin America & Caribbean', 27.5936666666667),
#  ('Solomon Islands', 'SB', 'East Asia & Pacific', 27.58625),
#  ('Kiribati', 'KI', 'East Asia & Pacific', 27.5316666666667),
#  ('Saudi Arabia', 'SA', 'Middle East & North Africa', 27.5300833333333),
#  ('Dominica', 'DM', 'Latin America & Caribbean', 27.4868333333333),
#  ('American Samoa', 'AS', 'East Asia & Pacific', 27.4534166666667),
#  ('Suriname', 'SR', 'Latin America & Caribbean', 27.4125833333333),
#  ('Thailand', 'TH', 'East Asia & Pacific', 27.3896666666667),
#  ('Philippines', 'PH', 'East Asia & Pacific', 27.3565),
#  ('Yemen', 'YE', 'Middle East & North Africa', 27.30275),
#  ('Northern Mariana Islands', 'MP', 'East Asia & Pacific', 27.2504166666667),
#  ('Guam', 'GU', 'East Asia & Pacific', 27.2504166666667),
#  ('Sierra Leone', 'SL', 'Sub-Saharan Africa', 27.1771666666667),
#  ('Samoa', 'WS', 'East Asia & Pacific', 27.1616666666667),
#  ('Guyana', 'GY', 'Latin America & Caribbean', 27.1160833333333),
#  ('Cayman Islands', 'KY', 'Latin America & Caribbean', 27.0344166666667),
#  ('Panama', 'PA', 'Latin America & Caribbean', 27.0291666666667),
#  ('Haiti', 'HT', 'Latin America & Caribbean', 27.0023333333333),
#  ('French Polynesia', 'PF', 'East Asia & Pacific', 26.9414166666667),
#  ('Malaysia', 'MY', 'East Asia & Pacific', 26.8066666666667),
#  ('Comoros', 'KM', 'Sub-Saharan Africa', 26.7868333333333),
#  ('Puerto Rico', 'PR', 'Latin America & Caribbean', 26.63825),
#  ('Nicaragua', 'NI', 'Latin America & Caribbean', 26.6189166666667),
#  ('Guinea', 'GN', 'Sub-Saharan Africa', 26.59725),
#  ('Indonesia', 'ID', 'East Asia & Pacific', 26.537),
#  ('Liberia', 'LR', 'Sub-Saharan Africa', 26.53275),
#  ('Jamaica', 'JM', 'Latin America & Caribbean', 26.52125),
#  ('Dominican Republic', 'DO', 'Latin America & Caribbean', 26.4555833333333),
#  ('Central African Republic', 'CF', 'Sub-Saharan Africa', 26.3298333333333),
#  ('Costa Rica', 'CR', 'Latin America & Caribbean', 26.22675),
#  ('Venezuela', 'VE', 'Latin America & Caribbean', 26.15025),
#  ('Bangladesh', 'BD', 'South Asia', 25.9403333333333),
#  ('Fiji', 'FJ', 'East Asia & Pacific', 25.9185),
#  ('Equatorial Guinea', 'GQ', 'Sub-Saharan Africa', 25.9025),
#  ('Brazil', 'BR', 'Latin America & Caribbean', 25.8124166666667),
#  ('Colombia', 'CO', 'Latin America & Caribbean', 25.6876666666667),
#  ('Cuba', 'CU', 'Latin America & Caribbean', 25.6273333333333),
#  ('Congo', 'CG', 'Sub-Saharan Africa', 25.5594166666667),
#  ('Belize', 'BZ', 'Latin America & Caribbean', 25.5023333333333),
#  ('Cameroon', 'CM', 'Sub-Saharan Africa', 25.46475),
#  ('El Salvador', 'SV', 'Latin America & Caribbean', 25.4586666666667),
#  ('Papua New Guinea', 'PG', 'East Asia & Pacific', 25.342),
#  ('Honduras', 'HN', 'Latin America & Caribbean', 25.2456666666667),
#  ('Gabon', 'GA', 'Sub-Saharan Africa', 25.221),
#  ('Algeria', 'DZ', 'Middle East & North Africa', 25.2156666666667),
#  ('Egypt', 'EG', 'Middle East & North Africa', 25.1519166666667),
#  ('India', 'IN', 'South Asia', 25.0508333333333),
#  ('Kenya', 'KE', 'Sub-Saharan Africa', 24.96125),
#  ('Vietnam', 'VN', 'East Asia & Pacific', 24.8333333333333),
#  ('Mauritius', 'MU', 'Sub-Saharan Africa', 24.6690833333333),
#  ('Iraq', 'IQ', 'Middle East & North Africa', 24.6503333333333),
#  ('Mozambique', 'MZ', 'Sub-Saharan Africa', 24.60575),
#  ('Libya', 'LY', 'Middle East & North Africa', 24.5159166666667),
#  ('Tonga', 'TO', 'East Asia & Pacific', 24.1144166666667),
#  ('Ethiopia', 'ET', 'Sub-Saharan Africa', 23.9275),
#  ('Uganda', 'UG', 'Sub-Saharan Africa', 23.9223333333333),
#  ('New Caledonia', 'NC', 'East Asia & Pacific', 23.8685),
#  ('Madagascar', 'MG', 'Sub-Saharan Africa', 23.8461666666667),
#  ('Guatemala', 'GT', 'Latin America & Caribbean', 23.6875833333333),
#  ('Paraguay', 'PY', 'Latin America & Caribbean', 23.6154166666667),
#  ('Tanzania', 'TZ', 'Sub-Saharan Africa', 23.2676666666667),
#  ('Botswana', 'BW', 'Sub-Saharan Africa', 22.7301666666667),
#  ('Angola', 'AO', 'Sub-Saharan Africa', 22.6815),
#  ('Ecuador', 'EC', 'Latin America & Caribbean', 22.6399166666667),
#  ('Malawi', 'MW', 'Sub-Saharan Africa', 22.6006666666667),
#  ('Israel', 'IL', 'Middle East & North Africa', 22.3111666666667),
#  ('Zambia', 'ZM', 'Sub-Saharan Africa', 22.2675),
#  ('Jordan', 'JO', 'Middle East & North Africa', 22.228),
#  ('Pakistan', 'PK', 'South Asia', 22.0879166666667),
#  ('Australia', 'AU', 'East Asia & Pacific', 22.0781666666667),
#  ('Zimbabwe', 'ZW', 'Sub-Saharan Africa', 21.98625),
#  ('Tunisia', 'TN', 'Middle East & North Africa', 21.60975),
#  ('Bolivia', 'BO', 'Latin America & Caribbean', 21.4464166666667),
#  ('Namibia', '', 'Sub-Saharan Africa', 21.39225),
#  ('Burundi', 'BI', 'Sub-Saharan Africa', 21.06875),
#  ('Cyprus', 'CY', 'Europe & Central Asia', 20.952),
#  ('Mexico', 'MX', 'Latin America & Caribbean', 20.8529166666667),
#  ('Peru', 'PE', 'Latin America & Caribbean', 20.5845),
#  ('Lebanon', 'LB', 'Middle East & North Africa', 20.2688333333333),
#  ('Rwanda', 'RW', 'Sub-Saharan Africa', 20.2670833333333),
#  ('Iran', 'IR', 'Middle East & North Africa', 20.0901666666667),
#  ('Swaziland', 'SZ', 'Sub-Saharan Africa', 19.7563333333333),
#  ('Malta', 'MT', 'Middle East & North Africa', 19.6644166666667),
#  ('Morocco', 'MA', 'Middle East & North Africa', 19.435),
#  ('South Africa', 'ZA', 'Sub-Saharan Africa', 18.3026666666667),
#  ('Uruguay', 'UY', 'Latin America & Caribbean', 17.9200833333333),
#  ('Turkmenistan', 'TM', 'Europe & Central Asia', 17.0438333333333),
#  ('Greece', 'GR', 'Europe & Central Asia', 16.37125),
#  ('Nepal', 'NP', 'South Asia', 16.114),
#  ('Afghanistan', 'AF', 'South Asia', 15.8286666666667),
#  ('Portugal', 'PT', 'Europe & Central Asia', 15.68425),
#  ('Argentina', 'AR', 'Latin America & Caribbean', 15.0788333333333),
#  ('Lesotho', 'LS', 'Sub-Saharan Africa', 14.9068333333333),
#  ('San Marino', 'SM', 'Europe & Central Asia', 14.4150833333333),
#  ('Uzbekistan', 'UZ', 'Europe & Central Asia', 14.3259166666667),
#  ('Turkey', 'TR', 'Europe & Central Asia', 14.2816666666667),
#  ('Spain', 'ES', 'Europe & Central Asia', 14.246),
#  ('Azerbaijan', 'AZ', 'Europe & Central Asia', 13.9626666666667),
#  ('Albania', 'AL', 'Europe & Central Asia', 13.7754166666667),
#  ('Italy', 'IT', 'Europe & Central Asia', 13.3249166666667),
#  ('Japan', 'JP', 'East Asia & Pacific', 13.2155833333333),
#  ('France', 'FR', 'Europe & Central Asia', 13.1154166666667),
#  ('Bhutan', 'BT', 'South Asia', 12.94725),
#  ('Croatia', 'HR', 'Europe & Central Asia', 11.9608333333333),
#  ('Bulgaria', 'BG', 'Europe & Central Asia', 11.7663333333333),
#  ('Macedonia', 'MK', 'Europe & Central Asia', 11.741),
#  ('Armenia', 'AM', 'Europe & Central Asia', 11.5095),
#  ('Andorra', 'AD', 'Europe & Central Asia', 11.4808333333333),
#  ('New Zealand', 'NZ', 'East Asia & Pacific', 11.33575),
#  ('Montenegro', 'ME', 'Europe & Central Asia', 11.2444166666667),
#  ('Georgia', 'GE', 'Europe & Central Asia', 11.1024166666667),
#  ('Serbia', 'RS', 'Europe & Central Asia', 10.9925),
#  ('Hungary', 'HU', 'Europe & Central Asia', 10.3478333333333),
#  ('Moldova', 'MD', 'Europe & Central Asia', 10.2256666666667),
#  ('Slovenia', 'SI', 'Europe & Central Asia', 10.194),
#  ('Romania', 'RO', 'Europe & Central Asia', 9.85166666666667),
#  ('Chile', 'CL', 'Latin America & Caribbean', 9.71283333333333),
#  ('United States', 'US', 'North America', 9.50558333333334),
#  ('Ukraine', 'UA', 'Europe & Central Asia', 9.453),
#  ('Belgium', 'BE', 'Europe & Central Asia', 9.36175),
#  ('Netherlands', 'NL', 'Europe & Central Asia', 9.26458333333333),
#  ('Ireland', 'IE', 'Europe & Central Asia', 9.25816666666667),
#  ('Monaco', 'MC', 'Europe & Central Asia', 9.22366666666666),
#  ('Luxembourg', 'LU', 'Europe & Central Asia', 9.13466666666667),
#  ('United Kingdom', 'GB', 'Europe & Central Asia', 8.39433333333333),
#  ('Germany', 'DE', 'Europe & Central Asia', 8.009),
#  ('Czech Republic', 'CZ', 'Europe & Central Asia', 7.75225),
#  ('Poland', 'PL', 'Europe & Central Asia', 7.62141666666667),
#  ('China', 'CN', 'East Asia & Pacific', 7.54841666666667),
#  ('Switzerland', 'CH', 'Europe & Central Asia', 7.2265),
#  ('Belarus', 'BY', 'Europe & Central Asia', 7.03725),
#  ('Kazakhstan', 'KZ', 'Europe & Central Asia', 6.71),
#  ('Austria', 'AT', 'Europe & Central Asia', 6.64908333333333),
#  ('Lithuania', 'LT', 'Europe & Central Asia', 6.32583333333333),
#  ('Latvia', 'LV', 'Europe & Central Asia', 5.71108333333333),
#  ('Tajikistan', 'TJ', 'Europe & Central Asia', 5.56408333333333),
#  ('Estonia', 'EE', 'Europe & Central Asia', 5.043),
#  ('Liechtenstein', 'LI', 'Europe & Central Asia', 4.84783333333333),
#  ('North America', 'XU', '', 4.07325),
#  ('Iceland', 'IS', 'Europe & Central Asia', 2.67641666666667),
#  ('Sweden', 'SE', 'Europe & Central Asia', 1.6585),
#  ('Finland', 'FI', 'Europe & Central Asia', 1.14375),
#  ('Norway', 'NO', 'Europe & Central Asia', -0.2155),
#  ('Mongolia', 'MN', 'East Asia & Pacific', -0.318666666666667),
#  ('Canada', 'CA', 'North America', -1.88791666666667),
#  ('Russia', 'RU', 'Europe & Central Asia', -4.52058333333333),
#  ('Denmark', 'DK', 'Europe & Central Asia', -15.08575),
#  ('Greenland', 'GL', 'Europe & Central Asia', -15.5463333333333)]

# %% [markdown]
# ## Yearly average temperature in Colombia
#
# Ordered from the most recent year to the oldest year.

# %%
# %%sql
# select co.short_name, da.year, avg(tem.avg_temperature) as temperature
# from dim_country co
#   join fact_temperatures_by_country tem on co.country_code = tem.country_code
#   join dim_date da on tem.full_date = da.full_date
# where co.short_name = 'Colombia'
# group by co.short_name, da.year
# order by da.year desc;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 174 rows affected.
# [('Colombia', 2013, 25.5795),
#  ('Colombia', 2012, 25.3813333333333),
#  ('Colombia', 2011, 25.2469166666667),
#  ('Colombia', 2010, 25.6876666666667),
#  ('Colombia', 2009, 25.6183333333333),
#  ('Colombia', 2008, 25.1539166666667),
#  ('Colombia', 2007, 25.494),
#  ('Colombia', 2006, 25.4765833333333),
#  ('Colombia', 2005, 25.6708333333333),
#  ('Colombia', 2004, 25.5539166666667),
#  ('Colombia', 2003, 25.6553333333333),
#  ('Colombia', 2002, 25.57075),
#  ('Colombia', 2001, 25.4119166666667),
#  ('Colombia', 2000, 25.0301666666667),
#  ('Colombia', 1999, 24.8706666666667),
#  ('Colombia', 1998, 25.8791666666667),
#  ('Colombia', 1997, 25.58),
#  ('Colombia', 1857, 23.8538333333333),
#  ('Colombia', 1856, 24.407),
#  ('Colombia', 1855, 24.4076666666667),
#  ('Colombia', 1854, 24.3221666666667),
#  ('Colombia', 1853, 24.2330833333333),
#  ('Colombia', 1852, 24.1495833333333),
#  ('Colombia', 1851, 24.3378333333333),
#  ('Colombia', 1850, 24.1405),
#  ('Colombia', 1849, 24.2249166666667),
#  ('Colombia', 1848, 24.10375),
#  ('Colombia', 1847, 24.1809166666667),
#  ('Colombia', 1846, 24.7671666666667),
#  ('Colombia', 1829, 24.2619),
#  ('Colombia', 1828, 24.4073636363636),
#  ('Colombia', 1827, 24.9519090909091),
#  ('Colombia', 1826, 24.5736),
#  ('Colombia', 1825, 24.6851666666667),
#  ('Colombia', 1824, 24.6683636363636)]

# %% [markdown]
# ## Cities in Colombia ordered according to their temperature in 2010?

# %%
# %%sql
# select tem.city, avg(tem.avg_temperature) as temperature
# from fact_temperatures_by_city tem
#   join dim_date da on tem.full_date = da.full_date
# where tem.country_code = 'COL' and da.year = 2010
# group by tem.city
# order by temperature desc;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 39 rows affected.
# [('Maicao', 28.9795833333333),
#  ('Sincelejo', 28.6755),
#  ('Montería', 28.6755),
#  ('Magangué', 28.6755),
#  ('Cartagena', 28.2005),
#  ('Barranquilla', 27.54175),
#  ('Santa Marta', 27.54175),
#  ('Malambo', 27.54175),
#  ('Soledad', 27.54175),
#  ('Valledupar', 27.4775833333333),
#  ('Girón', 26.2180833333333),
#  ('Floridablanca', 26.2180833333333),
#  ('Barrancabermeja', 26.2180833333333),
#  ('Bucaramanga', 26.2180833333333),
#  ('Neiva', 25.7355),
#  ('Villavicencio', 25.4716666666667),
#  ('Palmira', 22.6828333333333),
#  ('Cartago', 22.6828333333333),
#  ('Armenia', 22.6828333333333),
#  ('Cali', 22.6828333333333),
#  ('Buga', 22.6828333333333),
#  ('Tuluá', 22.6828333333333),
#  ('Buenaventura', 22.6828333333333),
#  ('Cúcuta', 21.88625),
#  ('Girardot', 20.95425),
#  ('Soacha', 20.95425),
#  ('Ibagué', 20.95425),
#  ('Bogotá', 20.95425),
#  ('Tunja', 20.3635),
#  ('Sogamoso', 20.3635),
#  ('Bello', 19.8740833333333),
#  ('Dos Quebradas', 19.8740833333333),
#  ('Medellín', 19.8740833333333),
#  ('Itagüí', 19.8740833333333),
#  ('Envigado', 19.8740833333333),
#  ('Manizales', 19.8740833333333),
#  ('Pereira', 19.8740833333333),
#  ('Florencia', 19.07875),
#  ('Pasto', 17.9149166666667)]

# %% [markdown]
# ## Coldest city in Colombia each year

# %%
# %%sql
# select t1.year, t2.city, t1.min_temp
# from
#   (select year, min(yearly_temperature) as min_temp
#   from
#     (select tem.city, da.year,
#            avg(tem.avg_temperature) as yearly_temperature
#     from fact_temperatures_by_city tem
#       join dim_date da on tem.full_date = da.full_date
#     where tem.country_code = 'COL'
#     group by tem.city, da.year) as temp_by_city_year
#   group by year) as t1
# join
#     (select tem.city, da.year,
#            avg(tem.avg_temperature) as yearly_temperature
#     from fact_temperatures_by_city tem
#       join dim_date da on tem.full_date = da.full_date
#     where tem.country_code = 'COL'
#     group by tem.city, da.year) as t2
# on (t1.year = t2.year and t1.min_temp = t2.yearly_temperature)
# order by t1.year desc
# Out:
#  * postgresql://dwhuser:***@dwhcluster.
#  (1886, 'Pasto', 16.5101666666667),
#  (1885, 'Florencia', 17.23875),
#  (1884, 'Pasto', 16.1858333333333),
#  (1883, 'Pasto', 16.1488333333333),
#  (1882, 'Pasto', 16.4156666666667),
#  (1881, 'Pasto', 16.8544166666667),
#  (1880, 'Pasto', 16.4932),
#  (1879, 'Pasto', 16.7454166666667),
#  (1878, 'Pasto', 17.572),
#  (1877, 'Pasto', 17.1039166666667),
#  (1876, 'Pasto', 16.6868333333333),
#  (1875, 'Pasto', 16.4073333333333),
#  (1874, 'Pasto', 16.6635555555556),
#  (1873, 'Pasto', 16.7353333333333),
#  (1872, 'Pasto', 16.8134166666667),
#  (1871, 'Pasto', 16.5161666666667),
#  (1870, 'Pasto', 16.5905833333333),
#  (1869, 'Pasto', 17.18325),
#  (1868, 'Pasto', 16.6978333333333),
#  (1867, 'Pasto', 16.8039166666667),
#  (1866, 'Pasto', 16.4390833333333),
#  (1865, 'Florencia', 17.7303333333333),
#  (1864, 'Pasto', 16.482),
#  (1863, 'Pasto', 16.5779166666667),
#  (1862, 'Florencia', 17.3764545454545),
#  (1861, 'Florencia', 17.616),
#  (1860, 'Pasto', 16.4246666666667),
#  (1859, 'Pasto', 16.5558333333333),
#  (1858, 'Pasto', 16.5518333333333),
#  (1857, 'Pasto', 16.2118181818182),
#  (1856, 'Pasto', 16.7561666666667),
#  (1855, 'Pasto', 16.7158181818182),
#  (1854, 'Pasto', 17.15),
#  (1853, 'Pasto', 16.4893333333333),
#  (1852, 'Pasto', 16.2626666666667),
#  (1851, 'Pereira', 18.57225),
#  (1851, 'Bello', 18.57225),
#  (1850, 'Sogamoso', 18.8143333333333),
#  (1850, 'Tunja', 18.8143333333333),
#  (1849, 'Sogamoso', 18.8974166666667),
#  (1848, 'Sogamoso', 18.77725),
#  (1847, 'Tunja', 18.8478333333333),
#  (1847, 'Sogamoso', 18.8478333333333),
#  (1846, 'Tunja', 19.4389166666667),
#  (1846, 'Sogamoso', 19.4389166666667),
#  (1829, 'Envigado', 18.4307),
#  (1828, 'Medellín', 18.6127272727273),
#  (1827, 'Manizales', 19.1314545454545),
#  (1827, 'Bello', 19.1314545454545),
#  (1826, 'Bello', 18.7976),
#  (1825, 'Dos Quebradas', 18.8801666666667),
#  (1825, 'Bello', 18.8801666666667),
#  (1824, 'Bello', 18.8348181818182),
#  (1824, 'Medellín', 18.8348181818182),
#  (1824, 'Pereira', 18.8348181818182),
#  (1824, 'Dos Quebradas', 18.8348181818182),
#  (1824, 'Itagüí', 18.8348181818182),
#  (1824, 'Manizales', 18.8348181818182),
#  (1824, 'Envigado', 18.8348181818182)]

# %% [markdown]
# ## Hottest city in Colombia each year

# %%
# %%sql
# select t1.year, t2.city, t1.max_temp
# from
#   (select year, max(yearly_temperature) as max_temp
#   from
#     (select tem.city, da.year,
#            avg(tem.avg_temperature) as yearly_temperature
#     from fact_temperatures_by_city tem
#       join dim_date da on tem.full_date = da.full_date
#     where tem.country_code = 'COL'
#     group by tem.city, da.year) as temp_by_city_year
#   group by year) as t1
# join
#     (select tem.city, da.year,
#            avg(tem.avg_temperature) as yearly_temperature
#     from fact_temperatures_by_city tem
#       join dim_date da on tem.full_date = da.full_date
#     where tem.country_code = 'COL'
#     group by tem.city, da.year) as t2
# on (t1.year = t2.year and t1.max_temp = t2.yearly_temperature)
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 174 rows affected.
# [(1997, 'Maicao', 29.0863333333333),
#  (1829, 'Maicao', 27.5374),
#  (1852, 'Maicao', 27.3898333333333),
#  (1928, 'Maicao', 28.1365833333333),
#  (2005, 'Maicao', 28.9426666666667),
#  (1972, 'Maicao', 28.6458333333333),
#  (1870, 'Maicao', 27.678),
#  (1941, 'Maicao', 28.9063333333333),
#  (1885, 'Maicao', 27.7466666666667),
#  (1991, 'Maicao', 28.66125),
#  (1960, 'Maicao', 28.1649166666667),
#  (2012, 'Maicao', 28.9276666666667),
#  (1953, 'Maicao', 28.69875),
#  (1962, 'Maicao', 28.4329166666667),
#  (1949, 'Maicao', 27.9654166666667),
#  (1910, 'Maicao', 27.60425),
#  (1865, 'Maicao', 27.7075833333333),
#  (1919, 'Maicao', 28.0388333333333),
#  (1848, 'Maicao', 27.5156666666667),
#  (1901, 'Maicao', 27.8575833333333),
#  (1894, 'Maicao', 27.3549166666667),
#  (1897, 'Maicao', 28.11675),
#  (1932, 'Maicao', 28.2014166666667),
#  (1925, 'Maicao', 27.8805833333333),
#  (1975, 'Maicao', 27.98775),
#  (2008, 'Maicao', 28.6096666666667),
#  (1893, 'Maicao', 27.355),
#  (1943, 'Maicao', 28.1505833333333),
#  (1877, 'Maicao', 28.3555833333333),
#  (1911, 'Maicao', 27.843),
#  (1998, 'Maicao', 29.143),
#  (1906, 'Maicao', 27.8855),
#  (1984, 'Maicao', 28.302),
#  (1878, 'Maicao', 28.7821666666667),
#  (1871, 'Maicao', 27.6315833333333),
#  (1954, 'Maicao', 28.3261666666667),
#  (1963, 'Maicao', 28.4603333333333),
#  (1977, 'Maicao', 28.6065833333333),
#  (1896, 'Maicao', 27.8663333333333),
#  (1920, 'Maicao', 27.863),
#  (2003, 'Maicao', 29.0725833333333),
#  (2001, 'Maicao', 28.8235833333333),
#  (1938, 'Maicao', 27.7634166666667),
#  (1891, 'Maicao', 27.9996666666667),
#  (1930, 'Maicao', 28.05525),
#  (1958, 'Maicao', 28.97125),
#  (1826, 'Maicao', 28.009),
#  (1828, 'Maicao', 27.9579090909091),
#  (1986, 'Magangué', 28.0359166666667),
#  (2006, 'Maicao', 28.9350833333333),
#  (1918, 'Maicao', 27.4656666666667),
#  (2004, 'Maicao', 28.7375),
#  (1935, 'Maicao', 27.8568333333333),
#  (1879, 'Maicao', 27.9790833333333),
#  (1976, 'Maicao', 28.1449166666667),
#  (1968, 'Maicao', 28.2729166666667),
#  (1931, 'Maicao', 28.3816666666667),
#  (1983, 'Maicao', 28.9495),
#  (1980, 'Maicao', 28.8455833333333),
#  (1971, 'Maicao', 28.1448333333333),
#  (1861, 'Maicao', 27.6373333333333),
#  (1926, 'Maicao', 28.4824166666667),
#  (1853, 'Maicao', 27.6398333333333),
#  (1851, 'Maicao', 27.7223333333333),
#  (1850, 'Maicao', 27.6365833333333),
#  (1884, 'Maicao', 27.3516666666667),
#  (1955, 'Maicao', 27.7795),
#  (1866, 'Maicao', 27.3364166666667),
#  (2009, 'Maicao', 29.1420833333333),
#  (1868, 'Maicao', 28.0290833333333),
#  (1902, 'Maicao', 28.00775),
#  (1933, 'Maicao', 27.9173333333333),
#  (1966, 'Maicao', 28.4330833333333),
#  (1978, 'Maicao', 28.5739166666667),
#  (1855, 'Maicao', 27.8096666666667),
#  (1872, 'Maicao', 28.1961666666667),
#  (1981, 'Maicao', 28.4889166666667),
#  (1969, 'Maicao', 28.7173333333333),
#  (1863, 'Maicao', 27.6759166666667),
#  (1921, 'Maicao', 27.68975),
#  (1908, 'Maicao', 27.7598333333333),
#  (1859, 'Maicao', 27.4093333333333),
#  (1985, 'Maicao', 28.08175),
#  (1913, 'Maicao', 27.6139166666667),
#  (1965, 'Maicao', 28.3008333333333),
#  (1970, 'Maicao', 28.61225),
#  (1912, 'Maicao', 28.0115),
#  (1994, 'Maicao', 28.6818333333333),
#  (1917, 'Maicao', 27.2718333333333),
#  (1956, 'Maicao', 28.0954166666667),
#  (1882, 'Maicao', 27.24925),
#  (1950, 'Maicao', 27.6413333333333),
#  (2000, 'Maicao', 28.3476666666667),
#  (1895, 'Maicao', 27.647),
#  (1914, 'Maicao', 28.064),
#  (1860, 'Maicao', 27.5095),
#  (1903, 'Maicao', 28.0931666666667),
#  (1947, 'Maicao', 28.52625),
#  (1999, 'Maicao', 28.2748333333333),
#  (1996, 'Maicao', 28.574),
#  (1964, 'Maicao', 28.2329166666667),
#  (1869, 'Maicao', 28.5024166666667),
#  (1862, 'Maicao', 27.482),
#  (1876, 'Maicao', 28.0445),
#  (1881, 'Maicao', 27.5355),
#  (1858, 'Maicao', 27.3280833333333),
#  (1934, 'Maicao', 28.0809166666667),
#  (1946, 'Maicao', 28.0191666666667),
#  (1846, 'Maicao', 28.0118333333333),
#  (1924, 'Maicao', 28.07875),
#  (1898, 'Maicao', 27.64075),
#  (1887, 'Maicao', 27.3575833333333),
#  (1959, 'Maicao', 28.2533333333333),
#  (1888, 'Maicao', 27.7633333333333),
#  (1849, 'Maicao', 27.7561666666667),
#  (2007, 'Maicao', 28.9511666666667),
#  (1864, 'Maicao', 27.6068333333333),
#  (2002, 'Maicao', 29.1353333333333),
#  (1883, 'Maicao', 27.584),
#  (1974, 'Maicao', 27.9139166666667),
#  (1847, 'Maicao', 27.5543333333333),
#  (1982, 'Maicao', 28.46975),
#  (1957, 'Maicao', 28.2399166666667),
#  (1992, 'Maicao', 28.7109166666667),
#  (1990, 'Maicao', 28.51425),
#  (1988, 'Maicao', 28.4645),
#  (1890, 'Maicao', 27.2826666666667),
#  (1827, 'Maicao', 28.2319090909091),
#  (1909, 'Maicao', 27.6043333333333),
#  (1937, 'Maicao', 28.1861666666667),
#  (1889, 'Maicao', 28.0514166666667),
#  (1886, 'Maicao', 27.5851666666667),
#  (2013, 'Maicao', 28.8834444444444),
#  (1995, 'Maicao', 28.7780833333333),
#  (1892, 'Maicao', 27.5529166666667),
#  (1923, 'Maicao', 27.9041666666667),
#  (1952, 'Maicao', 28.6760833333333),
#  (1873, 'Maicao', 27.65925),
#  (1993, 'Maicao', 28.8123333333333),
#  (1948, 'Maicao', 28.5121666666667),
#  (1939, 'Maicao', 28.0010833333333),
#  (1905, 'Maicao', 27.9461666666667),
#  (1961, 'Maicao', 28.2195),
#  (1944, 'Maicao', 28.1708333333333),
#  (1856, 'Maicao', 28.1794166666667),
#  (2011, 'Maicao', 28.5955),
#  (1927, 'Maicao', 27.97475),
#  (2010, 'Maicao', 28.9795833333333),
#  (1825, 'Maicao', 28.1111666666667),
#  (1951, 'Maicao', 28.36825),
#  (1987, 'Maicao', 28.98975),
#  (1973, 'Maicao', 28.5630833333333),
#  (1942, 'Maicao', 28.6166666666667),
#  (1945, 'Maicao', 27.9761666666667),
#  (1874, 'Maicao', 27.6669166666667),
#  (1904, 'Maicao', 27.5904166666667),
#  (1857, 'Maicao', 27.2325833333333),
#  (1967, 'Maicao', 28.2184166666667),
#  (1824, 'Maicao', 27.8961818181818),
#  (1922, 'Maicao', 27.8353333333333),
#  (1875, 'Maicao', 27.8278333333333),
#  (1915, 'Maicao', 28.4955),
#  (1880, 'Maicao', 27.472),
#  (1936, 'Maicao', 28.1269166666667),
#  (1867, 'Maicao', 27.7946666666667),
#  (1940, 'Maicao', 28.6985),
#  (1907, 'Maicao', 27.7391666666667),
#  (1899, 'Maicao', 27.8688333333333),
#  (1929, 'Maicao', 28.0249166666667),
#  (1854, 'Maicao', 27.6158333333333),
#  (1979, 'Maicao', 28.5490833333333),
#  (1916, 'Maicao', 27.7946666666667),
#  (1989, 'Maicao', 28.2943333333333),
#  (1900, 'Maicao', 28.2205)]

# %% [markdown]
# ## Happiest Countries in the world in 2017

# %%
# %%sql
# select dc.short_name, ind.value
# from fact_indicators ind
#   join dim_country dc on ind.country_code = dc.country_code
# where ind.indicator_name = 'Happiness Score' and ind.year = 2017
# order by ind.value desc
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 144 rows affected.
# [('Norway', 7.5370001793),
#  ('Denmark', 7.521999836),
#  ('Iceland', 7.5040001869),
#  ('Switzerland', 7.493999958),
#  ('Finland', 7.4689998627),
#  ('Netherlands', 7.376999855),
#  ('Canada', 7.3159999847),
#  ('New Zealand', 7.3140001297),
#  ('Sweden', 7.2839999199),
#  ('Australia', 7.2839999199),
#  ('Israel', 7.2129998207),
#  ('Costa Rica', 7.0789999962),
#  ('Austria', 7.006000042),
#  ('United States', 6.9930000305),
#  ('Ireland', 6.9770002365),
#  ('Germany', 6.9510002136),
#  ('Belgium', 6.890999794),
#  ('Luxembourg', 6.8629999161),
#  ('United Kingdom', 6.7140002251),
#  ('Chile', 6.6519999504),
#  ('United Arab Emirates', 6.6479997635),
#  ('Brazil', 6.6350002289),
#  ('Czech Republic', 6.609000206),
#  ('Argentina', 6.5989999771),
#  ('Mexico', 6.5780000687),
#  ('Singapore', 6.5720000267),
#  ('Malta', 6.5269999504),
#  ('Uruguay', 6.4539999962),
#  ('Guatemala', 6.4539999962),
#  ('Panama', 6.4520001411),
#  ('France', 6.4419999123),
#  ('Thailand', 6.4239997864),
#  ('Spain', 6.4029998779),
#  ('Qatar', 6.375),
#  ('Colombia', 6.3569998741),
#  ('Saudi Arabia', 6.3439998627),
#  ('Trinidad and Tobago', 6.1680002213),
#  ('Kuwait', 6.1050000191),
#  ('Bahrain', 6.0869998932),
#  ('Malaysia', 6.0840001106),
#  ('Nicaragua', 6.0710000992),
#  ('Ecuador', 6.007999897),
#  ('El Salvador', 6.0029997826),
#  ('Poland', 5.9730000496),
#  ('Uzbekistan', 5.9710001945),
#  ('Italy', 5.9640002251),
#  ('Russia', 5.9629998207),
#  ('Belize', 5.9559998512),
#  ('Japan', 5.9200000763),
#  ('Lithuania', 5.9019999504),
#  ('Algeria', 5.8720002174),
#  ('Latvia', 5.8499999046),
#  ('Moldova', 5.8379998207),
#  ('Romania', 5.8249998093),
#  ('Bolivia', 5.8229999542),
#  ('Turkmenistan', 5.8220000267),
#  ('Kazakhstan', 5.8189997673),
#  ('Slovenia', 5.757999897),
#  ('Peru', 5.7150001526),
#  ('Mauritius', 5.6290001869),
#  ('Cyprus', 5.6209998131),
#  ('Estonia', 5.611000061),
#  ('Belarus', 5.5689997673),
#  ('Libya', 5.5250000954),
#  ('Turkey', 5.5),
#  ('Paraguay', 5.4930000305),
#  ('Philippines', 5.4299998283),
#  ('Serbia', 5.3949999809),
#  ('Jordan', 5.3359999657),
#  ('Hungary', 5.3239998817),
#  ('Jamaica', 5.3109998703),
#  ('Croatia', 5.2930002213),
#  ('Kosovo', 5.2789998055),
#  ('China', 5.2729997635),
#  ('Pakistan', 5.2690000534),
#  ('Indonesia', 5.2620000839),
#  ('Venezuela', 5.25),
#  ('Montenegro', 5.2369999886),
#  ('Morocco', 5.2350001335),
#  ('Azerbaijan', 5.234000206),
#  ('Dominican Republic', 5.2300000191),
#  ('Greece', 5.2270002365),
#  ('Lebanon', 5.2249999046),
#  ('Portugal', 5.1950001717),
#  ('Bosnia and Herzegovina', 5.1820001602),
#  ('Honduras', 5.1810002327),
#  ('Macedonia', 5.1750001907),
#  ('Somalia', 5.1510000229),
#  ('Vietnam', 5.0739998817),
#  ('Nigeria', 5.0739998817),
#  ('Tajikistan', 5.0409998894),
#  ('Bhutan', 5.0110001564),
#  ('Nepal', 4.9619998932),
#  ('Mongolia', 4.9549999237),
#  ('South Africa', 4.8289999962),
#  ('Tunisia', 4.8049998283),
#  ('Egypt', 4.7350001335),
#  ('Bulgaria', 4.7140002251),
#  ('Sierra Leone', 4.7090001106),
#  ('Cameroon', 4.6950001717),
#  ('Iran', 4.6919999123),
#  ('Albania', 4.6440000534),
#  ('Bangladesh', 4.6079998016),
#  ('Namibia', 4.5739998817),
#  ('Kenya', 4.5529999733),
#  ('Mozambique', 4.5500001907),
#  ('Myanmar', 4.5450000763),
#  ('Senegal', 4.5349998474),
#  ('Zambia', 4.513999939),
#  ('Iraq', 4.4970002174),
#  ('Gabon', 4.4650001526),
#  ('Ethiopia', 4.4600000381),
#  ('Sri Lanka', 4.4400000572),
#  ('Armenia', 4.3759999275),
#  ('India', 4.3150000572),
#  ('Mauritania', 4.2919998169),
#  ('Georgia', 4.2859997749),
#  ('Mali', 4.1900000572),
#  ('Cambodia', 4.1680002213),
#  ('Sudan', 4.138999939),
#  ('Ghana', 4.1199998856),
#  ('Ukraine', 4.0960001945),
#  ('Uganda', 4.0809998512),
#  ('Burkina Faso', 4.0320000648),
#  ('Niger', 4.0279998779),
#  ('Malawi', 3.9700000286),
#  ('Chad', 3.9360001087),
#  ('Zimbabwe', 3.875),
#  ('Lesotho', 3.8080000877),
#  ('Angola', 3.7950000763),
#  ('Afghanistan', 3.7939999104),
#  ('Botswana', 3.7660000324),
#  ('Benin', 3.6570000648),
#  ('Madagascar', 3.6440000534),
#  ('Haiti', 3.6029999256),
#  ('Yemen', 3.5929999352),
#  ('South Sudan', 3.5910000801),
#  ('Liberia', 3.5329999924),
#  ('Guinea', 3.5069999695),
#  ('Togo', 3.4949998856),
#  ('Rwanda', 3.4709999561),
#  ('Tanzania', 3.3489999771),
#  ('Burundi', 2.9049999714),
#  ('Central African Republic', 2.6930000782)]

# %% [markdown]
# ## Relationship Between Happiness and Suicide Rate

# %%
# %%sql
# select happinness_score.year, happinness_score.short_name,
#        rate as suicide_rate, score as happiness_score
# from
#   (select dc.short_name, ind.year, avg(ind.value) as rate
#   from fact_indicators ind
#     join dim_country dc on ind.country_code = dc.country_code
#   where ind.indicator_name like 'Suicides 100k%'
#   group by dc.short_name, ind.year) as suicide_rate
# join
#   (select dc.short_name, ind.year, ind.value as score
#   from fact_indicators ind
#     join dim_country dc on ind.country_code = dc.country_code
#   where ind.indicator_name = 'Happiness Score') as happinness_score
# on (suicide_rate.short_name = happinness_score.short_name
#       and suicide_rate.year = happinness_score.year)
# order by happinness_score.year, happinness_score.score desc
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cex6w1axg6sf.us-west-2.redshift.amazonaws.com:5439/dwh
# 67 rows affected.
# [(2015, 'Switzerland', 13.7216666666667, 7.587),
#  (2015, 'Iceland', 11.7208333333333, 7.561),
#  (2015, 'Denmark', 10.1183333333333, 7.527),
#  (2015, 'Norway', 11.3691666666667, 7.522),
#  (2015, 'Finland', 13.4325, 7.406),
#  (2015, 'Netherlands', 10.5775, 7.378),
#  (2015, 'Sweden', 12.4416666666667, 7.364),
#  (2015, 'Australia', 12.8483333333333, 7.284),
#  (2015, 'Israel', 5.4925, 7.278),
#  (2015, 'Austria', 16.2183333333333, 7.2),
#  (2015, 'Mexico', 5.5475, 7.187),
#  (2015, 'United States', 14.6175, 7.119),
#  (2015, 'Brazil', 6.45416666666667, 6.983),
#  (2015, 'Luxembourg', 11.2, 6.946),
#  (2015, 'Belgium', 16.3883333333333, 6.937),
#  (2015, 'United Kingdom', 7.22833333333333, 6.867),
#  (2015, 'Singapore', 9.1075, 6.798),
#  (2015, 'Panama', 3.74166666666667, 6.786),
#  (2015, 'Germany', 12.5283333333333, 6.75),
#  (2015, 'Chile', 12.3066666666667, 6.67),
#  (2015, 'Qatar', 1.57, 6.611),
#  (2015, 'Argentina', 9.34416666666667, 6.574),
#  (2015, 'Czech Republic', 14.2391666666667, 6.505),
#  (2015, 'Uruguay', 22.5016666666667, 6.485),
#  (2015, 'Colombia', 5.86666666666667, 6.477),
#  (2015, 'Thailand', 6.7625, 6.455),
#  (2015, 'Spain', 8.115, 6.329),
#  (2015, 'Malta', 6.5225, 6.302),
#  (2015, 'Guatemala', 3.7375, 6.123),
#  (2015, 'Japan', 17.17, 5.987),
#  (2015, 'Ecuador', 8.11583333333333, 5.975),
#  (2015, 'Italy', 6.5375, 5.948),
#  (2015, 'Kazakhstan', 19.835, 5.855),
#  (2015, 'Slovenia', 22.0675, 5.848),
#  (2015, 'Lithuania', 32.1233333333333, 5.833),
#  (2015, 'Nicaragua', 5.8225, 5.828),
#  (2015, 'Poland', 13.9158333333333, 5.791),
#  (2015, 'Croatia', 19.14, 5.759),
#  (2015, 'Cyprus', 4.1325, 5.689),
#  (2015, 'Turkmenistan', 2.37333333333333, 5.548),
#  (2015, 'Mauritius', 8.33083333333333, 5.477),
#  (2015, 'Estonia', 17.115, 5.429),
#  (2015, 'Turkey', 2.3725, 5.332),
#  (2015, 'Romania', 11.1291666666667, 5.124),
#  (2015, 'Serbia', 17.1641666666667, 5.123),
#  (2015, 'Latvia', 20.9558333333333, 5.098),
#  (2015, 'Greece', 4.67166666666667, 4.857),
#  (2015, 'Hungary', 21.4391666666667, 4.8),
#  (2015, 'Ukraine', 20.3933333333333, 4.681),
#  (2015, 'South Africa', 1.08333333333333, 4.642),
#  (2015, 'Armenia', 3.77333333333333, 4.35),
#  (2015, 'Georgia', 7.05666666666667, 4.297),
#  (2016, 'Iceland', 13.807, 7.501),
#  (2016, 'Netherlands', 12.739, 7.339),
#  (2016, 'Sweden', 13.884, 7.291),
#  (2016, 'Austria', 18.323, 7.119),
#  (2016, 'Czech Republic', 16.176, 6.596),
#  (2016, 'Thailand', 7.732, 6.474),
#  (2016, 'Qatar', 1.643, 6.375),
#  (2016, 'Lithuania', 36.172, 5.813),
#  (2016, 'Mauritius', 9.93, 5.648),
#  (2016, 'Cyprus', 4.715, 5.546),
#  (2016, 'Romania', 11.633, 5.528),
#  (2016, 'Croatia', 21.356, 5.488),
#  (2016, 'Hungary', 24.134, 5.145),
#  (2016, 'Mongolia', 18.439, 4.907),
#  (2016, 'Armenia', 4.056, 4.36)]
